# %%
import numpy as np
import SpinModel_fm as smk
import matplotlib.pyplot as plt

# %%
cp_strg = [-0.5, -0.5, 0.5, 0, 0 ]
Hlsw = smk.fm_spin_model(cp_strg)

# %%
Hlsw
# Out:
# Matrix([
# [                                                                                                 1.25,                                -0.5*exp(I*(-k1/2 + sqrt(3)*k2/6)) - 0.75*exp(-sqrt(3)*I*k2/3),                                                                                                     0, -0.25*exp(I*(-k1/2 + sqrt(3)*k2/6)) + 0.25*exp(-sqrt(3)*I*k2/3) + 0.25*I*exp(-sqrt(3)*I*k2/3)],
# [   -0.5*exp(sqrt(3)*I*k2/3) - 0.25*exp(-I*(k1/2 + sqrt(3)*k2/6)) - 0.5*exp(-I*(-k1/2 + sqrt(3)*k2/6)),                                                                                          1.25, 0.25*exp(sqrt(3)*I*k2/3) + 0.25*I*exp(-I*(k1/2 + sqrt(3)*k2/6)) - 0.25*exp(-I*(-k1/2 + sqrt(3)*k2/6)),                                                                                             0],
# ...

# %%
val, vec = smk.bdg(Hlsw, 0, 0)

# %%
val
# Out:
# array([ 2.48746859e+00, -9.28398933e-17, -1.34443949e-16, -2.48746859e+00])

# %%
smk.band_high_sym(Hlsw, cp_strg)

# %%
smk.berry_curv(Hlsw, 0, 1, 3, 3)
# Out:
# array([ 0.02934602, -0.01939554])

# %%
smk.c2(Hlsw, 1,1, 1)
# Out:
# [ 2.58155251  0.35299548 -0.35299548 -2.58155251]
# [ 29.94840496   4.09507517  -4.09507517 -29.94840496]
# [ 9.85310216e-14  1.69365642e-02 -1.01693656e+00 -1.00000000e+00]
# array([1.64493406693669, 1.92923622585015], dtype=object)

# %%
smk.unnormalized_heat_conductivity(Hlsw, 0, 1, 1, 5)
# Out:
# [ 1.67705098  1.14564392 -1.14564392 -1.67705098]
# [ 19.45534783  13.29053276 -13.29053276 -19.45534783]
# [ 3.55344661e-09  1.69042418e-06 -1.00000169e+00 -1.00000000e+00]
# 0
# [0, 0]
# [0, 1] (0.08854653393762794-0.1400287555857903j)
# [0, 2] (0.08913736280339854-0.1417366773784594j)
# [0, 3] (0.08696493513234065-0.1410780067413493j)
# 1
# [1, 0] (0.08854653393762799+0.1400287555857903j)
# [1, 1]
# [1, 2] (0.08870118133116092+0.1400287555857903j)
# [1, 3] (0.08929201019693152+0.1383208337931212j)
# [ 1.59640364  1.20246228 -1.20246228 -1.59640364]
# [ 18.51976379  13.94967843 -13.94967843 -18.51976379]
# [ 9.05667502e-09  8.74444027e-07 -1.00000087e+00 -1.00000001e+00]
# 0
# [0, 0]
# [0, 1] (-0.3557822384548516-0.3048626943879109j)
# [0, 2] (-0.3553215981374111-0.30474956402729064j)
# [0, 3] (-0.3581473643515308-0.30498038095437374j)
# 1
# [1, 0] (-0.35578223845485163+0.3048626943879109j)
# [1, 1]
# [1, 2] (-0.3559450234321603+0.3038879906048832j)
# ...

# %%
smk.berry_curv_graph(Hlsw,1,0,1,10, 10)

# %%
smk.chern(Hlsw, 0,1, 15)

# %% [markdown]
# # Test for AFM
